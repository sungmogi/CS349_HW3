# %% [markdown]
# - Your architecture should consist of a single hidden layer with up to k nodes.
# - You can use any activation function (e.g., sigmoid, tanh, etc.) in the hidden nodes.
# - Your model must use a bias term at the input and hidden layers. It can be a standalone term or
# be incorporated in the weight matrices.
# - You should use gradient descent to train your FFNN.
# - You may find it helpful to use random number seeds for reproducibility when debugging.
# - You do not need to use a GPU for this assignment, and your models should train in less than one
# minute each.
# - You are responsible for selecting hyperparameters (e.g., number of hidden nodes, learning rate,
# training epochs, batch sizes, early stopping criteria, lambda, etc.). The goal is to get “good”
# performance from your model, but an exhaustive hyper-parameter search is unnecessary.
# - All code, exhibits and answers to free-response questions must be in a single Jupyter notebook.
# - Your code should use parameters to control all functionality needed to complete specific tasks
# (see below).

# %%
import torch

torch.manual_seed(42)

# %%
'''
Define model
'''

import torch
import torch.nn as nn
import torch.nn.functional as F

class SingleLayerFFNN(nn.Module):
    def __init__(self, hidden_size, activation_fn="sigmoid"):
        super(SingleLayerFFNN, self).__init__()

        self.input_layer = nn.Linear(2, hidden_size, bias=True)
        # self.output_layer = nn.Linear(hidden_size, 2, bias=True)
        self.output_layer = nn.Linear(hidden_size, 1, bias=True)

        if activation_fn == "sigmoid":
            self.activation = torch.sigmoid
        elif activation_fn == "tanh":
            self.activation = torch.tanh
        elif activation_fn == "relu":
            self.activation = torch.relu

    def forward(self, x):
        # One hidden layer
        hidden = self.activation(self.input_layer(x))
        output = torch.sigmoid(self.output_layer(hidden))

        return output

# %%
'''
Train model
'''

import torch.optim as optim

def train_model(model, train_loader, num_epochs, learning_rate):
    criterion = nn.MSELoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)

    for epoch in range(num_epochs):
        # loss for this epoch
        epoch_loss = 0
        for data, target in train_loader:
            target = target.float().unsqueeze(1)
            optimizer.zero_grad() # reset gradients
            output = model(data) # forward pass
            # print(output, target)
            loss = criterion(output, target) # calculate loss
 
            loss.backward() # backpropagation
            optimizer.step() # take step based on gradients and lr

            epoch_loss += loss.item()
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(train_loader):.4f}")

# %%
'''
Take in raw csv file path and batch size, return DataLoader object
'''

import csv
import torch
from torch.utils.data import DataLoader, TensorDataset

def load_data(file_path, batch_size):
    inputs = []
    labels = []

    with open(file_path, "r") as csvfile:
        reader = csv.reader(csvfile)
        next(reader) # skip header row
        for row in reader:
            labels.append(float(row[0]))
            inputs.append([float(row[1]), float(row[2])])

    inputs_tensor = torch.tensor(inputs, dtype=torch.float32)
    labels_tensor = torch.tensor(labels, dtype=torch.float32)

    dataset = TensorDataset(inputs_tensor, labels_tensor)
    loader = DataLoader(dataset, batch_size=batch_size)

    return loader

# %%
'''
Train model with train set. 
Hyperparameters: hidden_size, batch_size, num_epochs, learning_rate
'''

file_path = "spiral_train.csv"

# hidden_size from [2, 3, 5, 7, 9] 
hidden_size = 7
batch_size = 8
# activation from "sigmoid", "relu", "tanh"
activation_fn = "relu"
num_epochs = 300
learning_rate = 0.1

train_loader = load_data(file_path, batch_size)
model = SingleLayerFFNN(hidden_size, activation_fn)

train_model(model, train_loader, num_epochs, learning_rate)
# Out:
# Epoch 1/300, Loss: 0.2188
# Epoch 2/300, Loss: 0.1823
# Epoch 3/300, Loss: 0.1749
# Epoch 4/300, Loss: 0.1700
# Epoch 5/300, Loss: 0.1660
# Epoch 6/300, Loss: 0.1626
# Epoch 7/300, Loss: 0.1604
# Epoch 8/300, Loss: 0.1582
# Epoch 9/300, Loss: 0.1566
# Epoch 10/300, Loss: 0.1556
# Epoch 11/300, Loss: 0.1546
# Epoch 12/300, Loss: 0.1537
# Epoch 13/300, Loss: 0.1530
# Epoch 14/300, Loss: 0.1523
# Epoch 15/300, Loss: 0.1517
# Epoch 16/300, Loss: 0.1510
# Epoch 17/300, Loss: 0.1504
# Epoch 18/300, Loss: 0.1497
# Epoch 19/300, Loss: 0.1490
# Epoch 20/300, Loss: 0.1483
# Epoch 21/300, Loss: 0.1474
# Epoch 22/300, Loss: 0.1469
# Epoch 23/300, Loss: 0.1459
# Epoch 24/300, Loss: 0.1452
# Epoch 25/300, Loss: 0.1443
# Epoch 26/300, Loss: 0.1435
# Epoch 27/300, Loss: 0.1426
# Epoch 28/300, Loss: 0.1417
# Epoch 29/300, Loss: 0.1408
# Epoch 30/300, Loss: 0.1396
# Epoch 31/300, Loss: 0.1387
# Epoch 32/300, Loss: 0.1381
# Epoch 33/300, Loss: 0.1374
# Epoch 34/300, Loss: 0.1367
# Epoch 35/300, Loss: 0.1361
# Epoch 36/300, Loss: 0.1355
# Epoch 37/300, Loss: 0.1350
# Epoch 38/300, Loss: 0.1344
# Epoch 39/300, Loss: 0.1339
# Epoch 40/300, Loss: 0.1337
# Epoch 41/300, Loss: 0.1332
# Epoch 42/300, Loss: 0.1327
# Epoch 43/300, Loss: 0.1319
# Epoch 44/300, Loss: 0.1316
# Epoch 45/300, Loss: 0.1310
# Epoch 46/300, Loss: 0.1305
# Epoch 47/300, Loss: 0.1298
# Epoch 48/300, Loss: 0.1288
# Epoch 49/300, Loss: 0.1279
# Epoch 50/300, Loss: 0.1271
# Epoch 51/300, Loss: 0.1264
# Epoch 52/300, Loss: 0.1257
# Epoch 53/300, Loss: 0.1250
# Epoch 54/300, Loss: 0.1241
# Epoch 55/300, Loss: 0.1230
# Epoch 56/300, Loss: 0.1221
# Epoch 57/300, Loss: 0.1210
# Epoch 58/300, Loss: 0.1204
# Epoch 59/300, Loss: 0.1193
# Epoch 60/300, Loss: 0.1183
# Epoch 61/300, Loss: 0.1171
# Epoch 62/300, Loss: 0.1158
# Epoch 63/300, Loss: 0.1149
# Epoch 64/300, Loss: 0.1139
# Epoch 65/300, Loss: 0.1137
# Epoch 66/300, Loss: 0.1125
# Epoch 67/300, Loss: 0.1122
# Epoch 68/300, Loss: 0.1121
# Epoch 69/300, Loss: 0.1114
# Epoch 70/300, Loss: 0.1107
# Epoch 71/300, Loss: 0.1100
# Epoch 72/300, Loss: 0.1093
# Epoch 73/300, Loss: 0.1087
# Epoch 74/300, Loss: 0.1080
# Epoch 75/300, Loss: 0.1074
# Epoch 76/300, Loss: 0.1069
# Epoch 77/300, Loss: 0.1064
# Epoch 78/300, Loss: 0.1059
# Epoch 79/300, Loss: 0.1054
# Epoch 80/300, Loss: 0.1048
# Epoch 81/300, Loss: 0.1043
# Epoch 82/300, Loss: 0.1033
# Epoch 83/300, Loss: 0.1027
# Epoch 84/300, Loss: 0.1016
# Epoch 85/300, Loss: 0.1011
# Epoch 86/300, Loss: 0.1008
# Epoch 87/300, Loss: 0.0999
# Epoch 88/300, Loss: 0.1000
# Epoch 89/300, Loss: 0.0990
# Epoch 90/300, Loss: 0.0978
# Epoch 91/300, Loss: 0.0967
# Epoch 92/300, Loss: 0.0944
# Epoch 93/300, Loss: 0.0941
# Epoch 94/300, Loss: 0.0927
# Epoch 95/300, Loss: 0.0921
# Epoch 96/300, Loss: 0.0912
# Epoch 97/300, Loss: 0.0903
# Epoch 98/300, Loss: 0.0895
# Epoch 99/300, Loss: 0.0888
# Epoch 100/300, Loss: 0.0882
# Epoch 101/300, Loss: 0.0875
# Epoch 102/300, Loss: 0.0879
# Epoch 103/300, Loss: 0.0865
# Epoch 104/300, Loss: 0.0868
# Epoch 105/300, Loss: 0.0855
# Epoch 106/300, Loss: 0.0852
# Epoch 107/300, Loss: 0.0848
# Epoch 108/300, Loss: 0.0844
# Epoch 109/300, Loss: 0.0841
# Epoch 110/300, Loss: 0.0824
# Epoch 111/300, Loss: 0.0830
# Epoch 112/300, Loss: 0.0830
# Epoch 113/300, Loss: 0.0823
# Epoch 114/300, Loss: 0.0807
# Epoch 115/300, Loss: 0.0810
# Epoch 116/300, Loss: 0.0807
# Epoch 117/300, Loss: 0.0803
# Epoch 118/300, Loss: 0.0787
# Epoch 119/300, Loss: 0.0792
# Epoch 120/300, Loss: 0.0787
# Epoch 121/300, Loss: 0.0784
# Epoch 122/300, Loss: 0.0772
# Epoch 123/300, Loss: 0.0773
# Epoch 124/300, Loss: 0.0769
# Epoch 125/300, Loss: 0.0765
# Epoch 126/300, Loss: 0.0761
# Epoch 127/300, Loss: 0.0758
# Epoch 128/300, Loss: 0.0755
# Epoch 129/300, Loss: 0.0752
# Epoch 130/300, Loss: 0.0750
# Epoch 131/300, Loss: 0.0750
# Epoch 132/300, Loss: 0.0747
# Epoch 133/300, Loss: 0.0746
# Epoch 134/300, Loss: 0.0749
# Epoch 135/300, Loss: 0.0748
# Epoch 136/300, Loss: 0.0749
# Epoch 137/300, Loss: 0.0760
# Epoch 138/300, Loss: 0.0754
# Epoch 139/300, Loss: 0.0753
# Epoch 140/300, Loss: 0.0763
# Epoch 141/300, Loss: 0.0754
# Epoch 142/300, Loss: 0.0760
# Epoch 143/300, Loss: 0.0751
# Epoch 144/300, Loss: 0.0756
# Epoch 145/300, Loss: 0.0745
# Epoch 146/300, Loss: 0.0752
# Epoch 147/300, Loss: 0.0738
# Epoch 148/300, Loss: 0.0742
# Epoch 149/300, Loss: 0.0726
# Epoch 150/300, Loss: 0.0744
# Epoch 151/300, Loss: 0.0738
# Epoch 152/300, Loss: 0.0715
# Epoch 153/300, Loss: 0.0718
# Epoch 154/300, Loss: 0.0718
# Epoch 155/300, Loss: 0.0708
# Epoch 156/300, Loss: 0.0709
# Epoch 157/300, Loss: 0.0711
# Epoch 158/300, Loss: 0.0712
# Epoch 159/300, Loss: 0.0712
# Epoch 160/300, Loss: 0.0713
# Epoch 161/300, Loss: 0.0713
# Epoch 162/300, Loss: 0.0714
# Epoch 163/300, Loss: 0.0712
# Epoch 164/300, Loss: 0.0712
# Epoch 165/300, Loss: 0.0705
# Epoch 166/300, Loss: 0.0701
# Epoch 167/300, Loss: 0.0696
# Epoch 168/300, Loss: 0.0701
# Epoch 169/300, Loss: 0.0707
# Epoch 170/300, Loss: 0.0727
# Epoch 171/300, Loss: 0.0725
# Epoch 172/300, Loss: 0.0712
# Epoch 173/300, Loss: 0.0724
# Epoch 174/300, Loss: 0.0692
# Epoch 175/300, Loss: 0.0724
# Epoch 176/300, Loss: 0.0716
# Epoch 177/300, Loss: 0.0721
# Epoch 178/300, Loss: 0.0714
# Epoch 179/300, Loss: 0.0679
# Epoch 180/300, Loss: 0.0711
# Epoch 181/300, Loss: 0.0690
# Epoch 182/300, Loss: 0.0710
# Epoch 183/300, Loss: 0.0704
# Epoch 184/300, Loss: 0.0708
# Epoch 185/300, Loss: 0.0697
# Epoch 186/300, Loss: 0.0706
# Epoch 187/300, Loss: 0.0696
# Epoch 188/300, Loss: 0.0709
# Epoch 189/300, Loss: 0.0687
# Epoch 190/300, Loss: 0.0695
# Epoch 191/300, Loss: 0.0682
# Epoch 192/300, Loss: 0.0692
# Epoch 193/300, Loss: 0.0679
# Epoch 194/300, Loss: 0.0679
# Epoch 195/300, Loss: 0.0663
# Epoch 196/300, Loss: 0.0683
# Epoch 197/300, Loss: 0.0672
# Epoch 198/300, Loss: 0.0662
# Epoch 199/300, Loss: 0.0665
# Epoch 200/300, Loss: 0.0662
# Epoch 201/300, Loss: 0.0662
# Epoch 202/300, Loss: 0.0640
# Epoch 203/300, Loss: 0.0656
# Epoch 204/300, Loss: 0.0634
# Epoch 205/300, Loss: 0.0629
# Epoch 206/300, Loss: 0.0614
# Epoch 207/300, Loss: 0.0616
# Epoch 208/300, Loss: 0.0608
# Epoch 209/300, Loss: 0.0606
# Epoch 210/300, Loss: 0.0606
# Epoch 211/300, Loss: 0.0605
# Epoch 212/300, Loss: 0.0606
# Epoch 213/300, Loss: 0.0605
# Epoch 214/300, Loss: 0.0600
# Epoch 215/300, Loss: 0.0598
# Epoch 216/300, Loss: 0.0590
# Epoch 217/300, Loss: 0.0596
# Epoch 218/300, Loss: 0.0618
# Epoch 219/300, Loss: 0.0594
# Epoch 220/300, Loss: 0.0592
# Epoch 221/300, Loss: 0.0623
# Epoch 222/300, Loss: 0.0617
# Epoch 223/300, Loss: 0.0623
# Epoch 224/300, Loss: 0.0631
# Epoch 225/300, Loss: 0.0616
# Epoch 226/300, Loss: 0.0603
# Epoch 227/300, Loss: 0.0615
# Epoch 228/300, Loss: 0.0602
# Epoch 229/300, Loss: 0.0576
# Epoch 230/300, Loss: 0.0562
# Epoch 231/300, Loss: 0.0589
# Epoch 232/300, Loss: 0.0597
# Epoch 233/300, Loss: 0.0560
# Epoch 234/300, Loss: 0.0588
# Epoch 235/300, Loss: 0.0580
# Epoch 236/300, Loss: 0.0564
# Epoch 237/300, Loss: 0.0561
# Epoch 238/300, Loss: 0.0568
# Epoch 239/300, Loss: 0.0556
# Epoch 240/300, Loss: 0.0554
# Epoch 241/300, Loss: 0.0562
# Epoch 242/300, Loss: 0.0551
# Epoch 243/300, Loss: 0.0555
# Epoch 244/300, Loss: 0.0548
# Epoch 245/300, Loss: 0.0554
# Epoch 246/300, Loss: 0.0551
# Epoch 247/300, Loss: 0.0545
# Epoch 248/300, Loss: 0.0553
# Epoch 249/300, Loss: 0.0540
# Epoch 250/300, Loss: 0.0538
# Epoch 251/300, Loss: 0.0522
# Epoch 252/300, Loss: 0.0540
# Epoch 253/300, Loss: 0.0530
# Epoch 254/300, Loss: 0.0498
# Epoch 255/300, Loss: 0.0541
# Epoch 256/300, Loss: 0.0515
# Epoch 257/300, Loss: 0.0511
# Epoch 258/300, Loss: 0.0518
# Epoch 259/300, Loss: 0.0519
# Epoch 260/300, Loss: 0.0489
# Epoch 261/300, Loss: 0.0514
# Epoch 262/300, Loss: 0.0499
# Epoch 263/300, Loss: 0.0494
# Epoch 264/300, Loss: 0.0508
# Epoch 265/300, Loss: 0.0495
# Epoch 266/300, Loss: 0.0501
# Epoch 267/300, Loss: 0.0494
# Epoch 268/300, Loss: 0.0489
# Epoch 269/300, Loss: 0.0547
# Epoch 270/300, Loss: 0.0497
# Epoch 271/300, Loss: 0.0526
# Epoch 272/300, Loss: 0.0486
# Epoch 273/300, Loss: 0.0557
# Epoch 274/300, Loss: 0.0501
# Epoch 275/300, Loss: 0.0543
# Epoch 276/300, Loss: 0.0491
# Epoch 277/300, Loss: 0.0475
# Epoch 278/300, Loss: 0.0471
# Epoch 279/300, Loss: 0.0467
# Epoch 280/300, Loss: 0.0464
# Epoch 281/300, Loss: 0.0461
# Epoch 282/300, Loss: 0.0459
# Epoch 283/300, Loss: 0.0458
# Epoch 284/300, Loss: 0.0457
# Epoch 285/300, Loss: 0.0456
# Epoch 286/300, Loss: 0.0457
# Epoch 287/300, Loss: 0.0456
# Epoch 288/300, Loss: 0.0456
# Epoch 289/300, Loss: 0.0456
# Epoch 290/300, Loss: 0.0457
# Epoch 291/300, Loss: 0.0457
# Epoch 292/300, Loss: 0.0457
# Epoch 293/300, Loss: 0.0457
# Epoch 294/300, Loss: 0.0458
# Epoch 295/300, Loss: 0.0458
# Epoch 296/300, Loss: 0.0458
# Epoch 297/300, Loss: 0.0458
# Epoch 298/300, Loss: 0.0458
# Epoch 299/300, Loss: 0.0459
# Epoch 300/300, Loss: 0.0459

# %%
def evaluate_model(model, test_loader):
    model.eval()
    all_preds = []
    all_targets = []
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            # if output exceeds threshold 0.5, classify as 1
            preds = (output > 0.5).float()
            all_preds.extend(preds.numpy())
            all_targets.extend(target.numpy())

    all_preds = torch.tensor(all_preds).squeeze()
    all_targets = torch.tensor(all_targets)
    
    correct = (all_preds == all_targets).sum().item()
    total = len(all_targets)
    accuracy = correct / total
    
    print(f"Accuracy: {accuracy:.4f}")
    return accuracy

# %%
eval_file_path = "spiral_test.csv"
eval_batch_size = 4

eval_loader = load_data(eval_file_path, eval_batch_size)
evaluate_model(model, eval_loader)
# Out:
# Accuracy: 0.9600
# 0.96

# %%
import matplotlib.pyplot as plt

def plot_loss_curves(model, train_loader, val_loader, num_epochs, optimizer, criterion):
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        # Training loop
        model.train()
        running_train_loss = 0.0
        for data, target in train_loader:
            target = target.squeeze()
            optimizer.zero_grad()
            output = model(data).squeeze()
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            running_train_loss += loss.item()
        train_loss = running_train_loss / len(train_loader)
        train_losses.append(train_loss)
        
        # Validation loop
        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for data, target in val_loader:
                target = target.squeeze()
                output = model(data).squeeze()
                loss = criterion(output, target)
                running_val_loss += loss.item()
        val_loss = running_val_loss / len(val_loader)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch + 1}/{num_epochs} - Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
    
    # Plotting the loss curves
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
    plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return train_losses, val_losses

# %%
file_path = "spiral_train.csv"

hidden_size = 7
batch_size = 8
activation_fn = "relu"
num_epochs = 300
learning_rate = 0.1

eval_file_path = "spiral_valid.csv"
eval_batch_size = 4


train_loader = load_data(file_path, batch_size)
model = SingleLayerFFNN(hidden_size, activation_fn)
eval_loader = load_data(eval_file_path, eval_batch_size)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

plot_loss_curves(model, train_loader, eval_loader, num_epochs, optimizer, criterion)
# Out:
# Epoch 1/300 - Train Loss: 0.2613, Validation Loss: 0.1699
# Epoch 2/300 - Train Loss: 0.1654, Validation Loss: 0.1682
# Epoch 3/300 - Train Loss: 0.1639, Validation Loss: 0.1670
# Epoch 4/300 - Train Loss: 0.1629, Validation Loss: 0.1660
# Epoch 5/300 - Train Loss: 0.1620, Validation Loss: 0.1651
# Epoch 6/300 - Train Loss: 0.1611, Validation Loss: 0.1646
# Epoch 7/300 - Train Loss: 0.1603, Validation Loss: 0.1642
# Epoch 8/300 - Train Loss: 0.1597, Validation Loss: 0.1638
# Epoch 9/300 - Train Loss: 0.1593, Validation Loss: 0.1633
# Epoch 10/300 - Train Loss: 0.1587, Validation Loss: 0.1630
# Epoch 11/300 - Train Loss: 0.1583, Validation Loss: 0.1626
# Epoch 12/300 - Train Loss: 0.1578, Validation Loss: 0.1623
# Epoch 13/300 - Train Loss: 0.1575, Validation Loss: 0.1620
# Epoch 14/300 - Train Loss: 0.1571, Validation Loss: 0.1616
# Epoch 15/300 - Train Loss: 0.1567, Validation Loss: 0.1613
# Epoch 16/300 - Train Loss: 0.1564, Validation Loss: 0.1609
# Epoch 17/300 - Train Loss: 0.1559, Validation Loss: 0.1606
# Epoch 18/300 - Train Loss: 0.1556, Validation Loss: 0.1601
# Epoch 19/300 - Train Loss: 0.1551, Validation Loss: 0.1597
# Epoch 20/300 - Train Loss: 0.1547, Validation Loss: 0.1593
# Epoch 21/300 - Train Loss: 0.1542, Validation Loss: 0.1587
# Epoch 22/300 - Train Loss: 0.1536, Validation Loss: 0.1582
# Epoch 23/300 - Train Loss: 0.1530, Validation Loss: 0.1576
# Epoch 24/300 - Train Loss: 0.1524, Validation Loss: 0.1569
# Epoch 25/300 - Train Loss: 0.1517, Validation Loss: 0.1559
# Epoch 26/300 - Train Loss: 0.1511, Validation Loss: 0.1552
# Epoch 27/300 - Train Loss: 0.1505, Validation Loss: 0.1544
# Epoch 28/300 - Train Loss: 0.1500, Validation Loss: 0.1537
# Epoch 29/300 - Train Loss: 0.1496, Validation Loss: 0.1530
# Epoch 30/300 - Train Loss: 0.1489, Validation Loss: 0.1523
# Epoch 31/300 - Train Loss: 0.1485, Validation Loss: 0.1516
# Epoch 32/300 - Train Loss: 0.1480, Validation Loss: 0.1508
# Epoch 33/300 - Train Loss: 0.1475, Validation Loss: 0.1501
# Epoch 34/300 - Train Loss: 0.1471, Validation Loss: 0.1494
# Epoch 35/300 - Train Loss: 0.1469, Validation Loss: 0.1487
# Epoch 36/300 - Train Loss: 0.1465, Validation Loss: 0.1480
# Epoch 37/300 - Train Loss: 0.1462, Validation Loss: 0.1477
# Epoch 38/300 - Train Loss: 0.1454, Validation Loss: 0.1469
# Epoch 39/300 - Train Loss: 0.1448, Validation Loss: 0.1459
# Epoch 40/300 - Train Loss: 0.1448, Validation Loss: 0.1451
# Epoch 41/300 - Train Loss: 0.1445, Validation Loss: 0.1445
# Epoch 42/300 - Train Loss: 0.1439, Validation Loss: 0.1436
# Epoch 43/300 - Train Loss: 0.1438, Validation Loss: 0.1427
# Epoch 44/300 - Train Loss: 0.1430, Validation Loss: 0.1417
# Epoch 45/300 - Train Loss: 0.1422, Validation Loss: 0.1408
# Epoch 46/300 - Train Loss: 0.1418, Validation Loss: 0.1399
# Epoch 47/300 - Train Loss: 0.1412, Validation Loss: 0.1391
# Epoch 48/300 - Train Loss: 0.1407, Validation Loss: 0.1383
# Epoch 49/300 - Train Loss: 0.1401, Validation Loss: 0.1374
# Epoch 50/300 - Train Loss: 0.1397, Validation Loss: 0.1364
# Epoch 51/300 - Train Loss: 0.1389, Validation Loss: 0.1356
# Epoch 52/300 - Train Loss: 0.1383, Validation Loss: 0.1347
# Epoch 53/300 - Train Loss: 0.1378, Validation Loss: 0.1338
# Epoch 54/300 - Train Loss: 0.1373, Validation Loss: 0.1330
# Epoch 55/300 - Train Loss: 0.1367, Validation Loss: 0.1320
# Epoch 56/300 - Train Loss: 0.1361, Validation Loss: 0.1311
# Epoch 57/300 - Train Loss: 0.1357, Validation Loss: 0.1302
# Epoch 58/300 - Train Loss: 0.1351, Validation Loss: 0.1296
# Epoch 59/300 - Train Loss: 0.1348, Validation Loss: 0.1287
# Epoch 60/300 - Train Loss: 0.1342, Validation Loss: 0.1281
# Epoch 61/300 - Train Loss: 0.1339, Validation Loss: 0.1271
# Epoch 62/300 - Train Loss: 0.1332, Validation Loss: 0.1262
# Epoch 63/300 - Train Loss: 0.1322, Validation Loss: 0.1255
# Epoch 64/300 - Train Loss: 0.1316, Validation Loss: 0.1246
# Epoch 65/300 - Train Loss: 0.1310, Validation Loss: 0.1234
# Epoch 66/300 - Train Loss: 0.1301, Validation Loss: 0.1225
# Epoch 67/300 - Train Loss: 0.1294, Validation Loss: 0.1215
# Epoch 68/300 - Train Loss: 0.1287, Validation Loss: 0.1207
# Epoch 69/300 - Train Loss: 0.1278, Validation Loss: 0.1197
# Epoch 70/300 - Train Loss: 0.1269, Validation Loss: 0.1196
# Epoch 71/300 - Train Loss: 0.1262, Validation Loss: 0.1187
# Epoch 72/300 - Train Loss: 0.1254, Validation Loss: 0.1181
# Epoch 73/300 - Train Loss: 0.1246, Validation Loss: 0.1173
# Epoch 74/300 - Train Loss: 0.1237, Validation Loss: 0.1166
# Epoch 75/300 - Train Loss: 0.1229, Validation Loss: 0.1158
# Epoch 76/300 - Train Loss: 0.1221, Validation Loss: 0.1151
# Epoch 77/300 - Train Loss: 0.1213, Validation Loss: 0.1140
# Epoch 78/300 - Train Loss: 0.1207, Validation Loss: 0.1133
# Epoch 79/300 - Train Loss: 0.1198, Validation Loss: 0.1123
# Epoch 80/300 - Train Loss: 0.1190, Validation Loss: 0.1116
# Epoch 81/300 - Train Loss: 0.1185, Validation Loss: 0.1100
# Epoch 82/300 - Train Loss: 0.1174, Validation Loss: 0.1090
# Epoch 83/300 - Train Loss: 0.1165, Validation Loss: 0.1082
# Epoch 84/300 - Train Loss: 0.1157, Validation Loss: 0.1073
# Epoch 85/300 - Train Loss: 0.1149, Validation Loss: 0.1065
# Epoch 86/300 - Train Loss: 0.1141, Validation Loss: 0.1056
# Epoch 87/300 - Train Loss: 0.1134, Validation Loss: 0.1049
# Epoch 88/300 - Train Loss: 0.1126, Validation Loss: 0.1041
# Epoch 89/300 - Train Loss: 0.1119, Validation Loss: 0.1034
# Epoch 90/300 - Train Loss: 0.1110, Validation Loss: 0.1027
# Epoch 91/300 - Train Loss: 0.1104, Validation Loss: 0.1020
# Epoch 92/300 - Train Loss: 0.1095, Validation Loss: 0.1015
# Epoch 93/300 - Train Loss: 0.1088, Validation Loss: 0.1007
# Epoch 94/300 - Train Loss: 0.1082, Validation Loss: 0.1003
# Epoch 95/300 - Train Loss: 0.1072, Validation Loss: 0.0993
# Epoch 96/300 - Train Loss: 0.1065, Validation Loss: 0.0989
# Epoch 97/300 - Train Loss: 0.1059, Validation Loss: 0.0983
# Epoch 98/300 - Train Loss: 0.1049, Validation Loss: 0.0976
# Epoch 99/300 - Train Loss: 0.1043, Validation Loss: 0.0969
# Epoch 100/300 - Train Loss: 0.1034, Validation Loss: 0.0961
# Epoch 101/300 - Train Loss: 0.1026, Validation Loss: 0.0955
# Epoch 102/300 - Train Loss: 0.1021, Validation Loss: 0.0948
# Epoch 103/300 - Train Loss: 0.1010, Validation Loss: 0.0940
# Epoch 104/300 - Train Loss: 0.1003, Validation Loss: 0.0933
# Epoch 105/300 - Train Loss: 0.0998, Validation Loss: 0.0926
# Epoch 106/300 - Train Loss: 0.0987, Validation Loss: 0.0918
# Epoch 107/300 - Train Loss: 0.0980, Validation Loss: 0.0911
# Epoch 108/300 - Train Loss: 0.0973, Validation Loss: 0.0906
# Epoch 109/300 - Train Loss: 0.0963, Validation Loss: 0.0897
# Epoch 110/300 - Train Loss: 0.0956, Validation Loss: 0.0889
# Epoch 111/300 - Train Loss: 0.0949, Validation Loss: 0.0881
# Epoch 112/300 - Train Loss: 0.0944, Validation Loss: 0.0875
# Epoch 113/300 - Train Loss: 0.0941, Validation Loss: 0.0871
# Epoch 114/300 - Train Loss: 0.0927, Validation Loss: 0.0859
# Epoch 115/300 - Train Loss: 0.0929, Validation Loss: 0.0857
# Epoch 116/300 - Train Loss: 0.0922, Validation Loss: 0.0848
# Epoch 117/300 - Train Loss: 0.0916, Validation Loss: 0.0841
# Epoch 118/300 - Train Loss: 0.0911, Validation Loss: 0.0836
# Epoch 119/300 - Train Loss: 0.0909, Validation Loss: 0.0833
# Epoch 120/300 - Train Loss: 0.0902, Validation Loss: 0.0823
# Epoch 121/300 - Train Loss: 0.0897, Validation Loss: 0.0817
# Epoch 122/300 - Train Loss: 0.0894, Validation Loss: 0.0815
# Epoch 123/300 - Train Loss: 0.0889, Validation Loss: 0.0806
# Epoch 124/300 - Train Loss: 0.0884, Validation Loss: 0.0800
# Epoch 125/300 - Train Loss: 0.0879, Validation Loss: 0.0796
# Epoch 126/300 - Train Loss: 0.0876, Validation Loss: 0.0787
# Epoch 127/300 - Train Loss: 0.0869, Validation Loss: 0.0776
# Epoch 128/300 - Train Loss: 0.0835, Validation Loss: 0.0767
# Epoch 129/300 - Train Loss: 0.0833, Validation Loss: 0.0763
# Epoch 130/300 - Train Loss: 0.0830, Validation Loss: 0.0759
# Epoch 131/300 - Train Loss: 0.0826, Validation Loss: 0.0755
# Epoch 132/300 - Train Loss: 0.0823, Validation Loss: 0.0751
# Epoch 133/300 - Train Loss: 0.0819, Validation Loss: 0.0747
# Epoch 134/300 - Train Loss: 0.0816, Validation Loss: 0.0744
# Epoch 135/300 - Train Loss: 0.0813, Validation Loss: 0.0741
# Epoch 136/300 - Train Loss: 0.0811, Validation Loss: 0.0773
# Epoch 137/300 - Train Loss: 0.0804, Validation Loss: 0.0769
# Epoch 138/300 - Train Loss: 0.0794, Validation Loss: 0.0744
# Epoch 139/300 - Train Loss: 0.0790, Validation Loss: 0.0740
# Epoch 140/300 - Train Loss: 0.0786, Validation Loss: 0.0737
# Epoch 141/300 - Train Loss: 0.0784, Validation Loss: 0.0734
# Epoch 142/300 - Train Loss: 0.0782, Validation Loss: 0.0724
# Epoch 143/300 - Train Loss: 0.0772, Validation Loss: 0.0716
# Epoch 144/300 - Train Loss: 0.0767, Validation Loss: 0.0721
# Epoch 145/300 - Train Loss: 0.0767, Validation Loss: 0.0718
# Epoch 146/300 - Train Loss: 0.0766, Validation Loss: 0.0720
# Epoch 147/300 - Train Loss: 0.0766, Validation Loss: 0.0722
# Epoch 148/300 - Train Loss: 0.0765, Validation Loss: 0.0718
# Epoch 149/300 - Train Loss: 0.0763, Validation Loss: 0.0718
# Epoch 150/300 - Train Loss: 0.0762, Validation Loss: 0.0719
# Epoch 151/300 - Train Loss: 0.0762, Validation Loss: 0.0714
# Epoch 152/300 - Train Loss: 0.0757, Validation Loss: 0.0683
# Epoch 153/300 - Train Loss: 0.0748, Validation Loss: 0.0658
# Epoch 154/300 - Train Loss: 0.0737, Validation Loss: 0.0644
# Epoch 155/300 - Train Loss: 0.0750, Validation Loss: 0.0638
# Epoch 156/300 - Train Loss: 0.0738, Validation Loss: 0.0635
# Epoch 157/300 - Train Loss: 0.0741, Validation Loss: 0.0638
# Epoch 158/300 - Train Loss: 0.0728, Validation Loss: 0.0650
# Epoch 159/300 - Train Loss: 0.0723, Validation Loss: 0.0650
# Epoch 160/300 - Train Loss: 0.0720, Validation Loss: 0.0671
# Epoch 161/300 - Train Loss: 0.0719, Validation Loss: 0.0682
# Epoch 162/300 - Train Loss: 0.0726, Validation Loss: 0.0702
# Epoch 163/300 - Train Loss: 0.0720, Validation Loss: 0.0713
# Epoch 164/300 - Train Loss: 0.0717, Validation Loss: 0.0714
# Epoch 165/300 - Train Loss: 0.0714, Validation Loss: 0.0711
# Epoch 166/300 - Train Loss: 0.0712, Validation Loss: 0.0704
# Epoch 167/300 - Train Loss: 0.0715, Validation Loss: 0.0709
# Epoch 168/300 - Train Loss: 0.0708, Validation Loss: 0.0707
# Epoch 169/300 - Train Loss: 0.0705, Validation Loss: 0.0697
# Epoch 170/300 - Train Loss: 0.0710, Validation Loss: 0.0704
# Epoch 171/300 - Train Loss: 0.0702, Validation Loss: 0.0690
# Epoch 172/300 - Train Loss: 0.0707, Validation Loss: 0.0698
# Epoch 173/300 - Train Loss: 0.0698, Validation Loss: 0.0686
# Epoch 174/300 - Train Loss: 0.0696, Validation Loss: 0.0673
# Epoch 175/300 - Train Loss: 0.0703, Validation Loss: 0.0682
# Epoch 176/300 - Train Loss: 0.0691, Validation Loss: 0.0655
# Epoch 177/300 - Train Loss: 0.0699, Validation Loss: 0.0655
# Epoch 178/300 - Train Loss: 0.0695, Validation Loss: 0.0652
# Epoch 179/300 - Train Loss: 0.0699, Validation Loss: 0.0649
# Epoch 180/300 - Train Loss: 0.0696, Validation Loss: 0.0648
# Epoch 181/300 - Train Loss: 0.0683, Validation Loss: 0.0625
# Epoch 182/300 - Train Loss: 0.0696, Validation Loss: 0.0628
# Epoch 183/300 - Train Loss: 0.0688, Validation Loss: 0.0625
# Epoch 184/300 - Train Loss: 0.0693, Validation Loss: 0.0622
# Epoch 185/300 - Train Loss: 0.0689, Validation Loss: 0.0619
# Epoch 186/300 - Train Loss: 0.0693, Validation Loss: 0.0616
# Epoch 187/300 - Train Loss: 0.0673, Validation Loss: 0.0600
# Epoch 188/300 - Train Loss: 0.0686, Validation Loss: 0.0601
# Epoch 189/300 - Train Loss: 0.0677, Validation Loss: 0.0597
# Epoch 190/300 - Train Loss: 0.0670, Validation Loss: 0.0593
# Epoch 191/300 - Train Loss: 0.0675, Validation Loss: 0.0590
# Epoch 192/300 - Train Loss: 0.0664, Validation Loss: 0.0585
# Epoch 193/300 - Train Loss: 0.0667, Validation Loss: 0.0583
# Epoch 194/300 - Train Loss: 0.0664, Validation Loss: 0.0580
# Epoch 195/300 - Train Loss: 0.0657, Validation Loss: 0.0577
# Epoch 196/300 - Train Loss: 0.0659, Validation Loss: 0.0575
# Epoch 197/300 - Train Loss: 0.0657, Validation Loss: 0.0573
# Epoch 198/300 - Train Loss: 0.0651, Validation Loss: 0.0570
# Epoch 199/300 - Train Loss: 0.0652, Validation Loss: 0.0570
# Epoch 200/300 - Train Loss: 0.0648, Validation Loss: 0.0568
# Epoch 201/300 - Train Loss: 0.0644, Validation Loss: 0.0564
# Epoch 202/300 - Train Loss: 0.0641, Validation Loss: 0.0560
# Epoch 203/300 - Train Loss: 0.0640, Validation Loss: 0.0557
# Epoch 204/300 - Train Loss: 0.0638, Validation Loss: 0.0554
# Epoch 205/300 - Train Loss: 0.0636, Validation Loss: 0.0551
# Epoch 206/300 - Train Loss: 0.0637, Validation Loss: 0.0551
# Epoch 207/300 - Train Loss: 0.0632, Validation Loss: 0.0546
# Epoch 208/300 - Train Loss: 0.0631, Validation Loss: 0.0546
# Epoch 209/300 - Train Loss: 0.0628, Validation Loss: 0.0541
# Epoch 210/300 - Train Loss: 0.0627, Validation Loss: 0.0543
# Epoch 211/300 - Train Loss: 0.0623, Validation Loss: 0.0537
# Epoch 212/300 - Train Loss: 0.0624, Validation Loss: 0.0540
# Epoch 213/300 - Train Loss: 0.0619, Validation Loss: 0.0530
# Epoch 214/300 - Train Loss: 0.0619, Validation Loss: 0.0536
# Epoch 215/300 - Train Loss: 0.0615, Validation Loss: 0.0527
# Epoch 216/300 - Train Loss: 0.0615, Validation Loss: 0.0534
# Epoch 217/300 - Train Loss: 0.0611, Validation Loss: 0.0523
# Epoch 218/300 - Train Loss: 0.0610, Validation Loss: 0.0529
# Epoch 219/300 - Train Loss: 0.0607, Validation Loss: 0.0518
# Epoch 220/300 - Train Loss: 0.0602, Validation Loss: 0.0533
# Epoch 221/300 - Train Loss: 0.0601, Validation Loss: 0.0514
# Epoch 222/300 - Train Loss: 0.0598, Validation Loss: 0.0528
# Epoch 223/300 - Train Loss: 0.0596, Validation Loss: 0.0510
# Epoch 224/300 - Train Loss: 0.0594, Validation Loss: 0.0528
# Epoch 225/300 - Train Loss: 0.0590, Validation Loss: 0.0507
# Epoch 226/300 - Train Loss: 0.0594, Validation Loss: 0.0522
# Epoch 227/300 - Train Loss: 0.0587, Validation Loss: 0.0511
# Epoch 228/300 - Train Loss: 0.0589, Validation Loss: 0.0509
# Epoch 229/300 - Train Loss: 0.0582, Validation Loss: 0.0519
# Epoch 230/300 - Train Loss: 0.0580, Validation Loss: 0.0500
# Epoch 231/300 - Train Loss: 0.0578, Validation Loss: 0.0512
# Epoch 232/300 - Train Loss: 0.0572, Validation Loss: 0.0496
# Epoch 233/300 - Train Loss: 0.0571, Validation Loss: 0.0518
# Epoch 234/300 - Train Loss: 0.0572, Validation Loss: 0.0503
# Epoch 235/300 - Train Loss: 0.0568, Validation Loss: 0.0505
# Epoch 236/300 - Train Loss: 0.0570, Validation Loss: 0.0518
# Epoch 237/300 - Train Loss: 0.0568, Validation Loss: 0.0495
# Epoch 238/300 - Train Loss: 0.0568, Validation Loss: 0.0525
# Epoch 239/300 - Train Loss: 0.0561, Validation Loss: 0.0493
# Epoch 240/300 - Train Loss: 0.0564, Validation Loss: 0.0520
# Epoch 241/300 - Train Loss: 0.0558, Validation Loss: 0.0490
# Epoch 242/300 - Train Loss: 0.0564, Validation Loss: 0.0519
# Epoch 243/300 - Train Loss: 0.0553, Validation Loss: 0.0488
# Epoch 244/300 - Train Loss: 0.0559, Validation Loss: 0.0523
# Epoch 245/300 - Train Loss: 0.0547, Validation Loss: 0.0485
# Epoch 246/300 - Train Loss: 0.0554, Validation Loss: 0.0522
# Epoch 247/300 - Train Loss: 0.0547, Validation Loss: 0.0491
# Epoch 248/300 - Train Loss: 0.0562, Validation Loss: 0.0528
# Epoch 249/300 - Train Loss: 0.0527, Validation Loss: 0.0486
# Epoch 250/300 - Train Loss: 0.0552, Validation Loss: 0.0524
# Epoch 251/300 - Train Loss: 0.0520, Validation Loss: 0.0497
# Epoch 252/300 - Train Loss: 0.0539, Validation Loss: 0.0521
# Epoch 253/300 - Train Loss: 0.0526, Validation Loss: 0.0489
# Epoch 254/300 - Train Loss: 0.0543, Validation Loss: 0.0520
# Epoch 255/300 - Train Loss: 0.0515, Validation Loss: 0.0495
# Epoch 256/300 - Train Loss: 0.0531, Validation Loss: 0.0522
# Epoch 257/300 - Train Loss: 0.0516, Validation Loss: 0.0491
# Epoch 258/300 - Train Loss: 0.0535, Validation Loss: 0.0521
# Epoch 259/300 - Train Loss: 0.0504, Validation Loss: 0.0495
# Epoch 260/300 - Train Loss: 0.0519, Validation Loss: 0.0530
# Epoch 261/300 - Train Loss: 0.0506, Validation Loss: 0.0484
# Epoch 262/300 - Train Loss: 0.0513, Validation Loss: 0.0522
# Epoch 263/300 - Train Loss: 0.0515, Validation Loss: 0.0486
# Epoch 264/300 - Train Loss: 0.0527, Validation Loss: 0.0533
# Epoch 265/300 - Train Loss: 0.0492, Validation Loss: 0.0491
# Epoch 266/300 - Train Loss: 0.0502, Validation Loss: 0.0506
# Epoch 267/300 - Train Loss: 0.0491, Validation Loss: 0.0510
# Epoch 268/300 - Train Loss: 0.0494, Validation Loss: 0.0513
# Epoch 269/300 - Train Loss: 0.0491, Validation Loss: 0.0526
# Epoch 270/300 - Train Loss: 0.0490, Validation Loss: 0.0530
# Epoch 271/300 - Train Loss: 0.0497, Validation Loss: 0.0512
# Epoch 272/300 - Train Loss: 0.0494, Validation Loss: 0.0506
# Epoch 273/300 - Train Loss: 0.0491, Validation Loss: 0.0499
# Epoch 274/300 - Train Loss: 0.0515, Validation Loss: 0.0494
# Epoch 275/300 - Train Loss: 0.0524, Validation Loss: 0.0495
# Epoch 276/300 - Train Loss: 0.0501, Validation Loss: 0.0491
# Epoch 277/300 - Train Loss: 0.0472, Validation Loss: 0.0500
# Epoch 278/300 - Train Loss: 0.0473, Validation Loss: 0.0501
# Epoch 279/300 - Train Loss: 0.0473, Validation Loss: 0.0499
# Epoch 280/300 - Train Loss: 0.0473, Validation Loss: 0.0496
# Epoch 281/300 - Train Loss: 0.0467, Validation Loss: 0.0496
# Epoch 282/300 - Train Loss: 0.0466, Validation Loss: 0.0493
# Epoch 283/300 - Train Loss: 0.0467, Validation Loss: 0.0487
# Epoch 284/300 - Train Loss: 0.0463, Validation Loss: 0.0485
# Epoch 285/300 - Train Loss: 0.0460, Validation Loss: 0.0482
# Epoch 286/300 - Train Loss: 0.0462, Validation Loss: 0.0476
# Epoch 287/300 - Train Loss: 0.0458, Validation Loss: 0.0472
# Epoch 288/300 - Train Loss: 0.0455, Validation Loss: 0.0468
# Epoch 289/300 - Train Loss: 0.0461, Validation Loss: 0.0456
# Epoch 290/300 - Train Loss: 0.0520, Validation Loss: 0.0443
# Epoch 291/300 - Train Loss: 0.0421, Validation Loss: 0.0446
# Epoch 292/300 - Train Loss: 0.0561, Validation Loss: 0.0465
# Epoch 293/300 - Train Loss: 0.0424, Validation Loss: 0.0474
# Epoch 294/300 - Train Loss: 0.0613, Validation Loss: 0.0458
# Epoch 295/300 - Train Loss: 0.0462, Validation Loss: 0.0493
# Epoch 296/300 - Train Loss: 0.0453, Validation Loss: 0.0458
# Epoch 297/300 - Train Loss: 0.0485, Validation Loss: 0.0456
# Epoch 298/300 - Train Loss: 0.0459, Validation Loss: 0.0432
# Epoch 299/300 - Train Loss: 0.0450, Validation Loss: 0.0453
# Epoch 300/300 - Train Loss: 0.0444, Validation Loss: 0.0436
# ([0.26127158001065254,
#   0.16538689464330672,
#   0.16391509413719177,
#   0.16291143625974655,
#   0.16202162638306616,
#   0.1610888248682022,
#   0.16034367352724074,
#   0.15973322242498397,
#   0.15926985025405885,
#   0.15865851283073426,
#   0.1583251239359379,
#   0.15778356075286865,
#   0.15747045144438743,
#   0.1570708215236664,
#   0.15667616382241248,
#   0.15641274243593217,
#   0.1559393486380577,
#   0.15559591650962828,
#   0.15511501595377922,
#   0.1547005879878998,
#   0.15419138774275779,
#   0.15357788726687432,
#   0.1529647509753704,
#   0.15241291016340255,
#   0.15171217560768127,
#   0.1511133162677288,
#   0.15047585636377334,
#   0.14995941758155823,
#   0.149598381370306,
#   0.14888310089707374,
#   0.14845293298363685,
#   0.14801706701517106,
#   0.14754697695374488,
#   0.14707929953932763,
#   0.14691426753997802,
#   0.1464664037525654,
#   0.14620550692081452,
#   0.14544324204325676,
#   0.1447889506816864,
#   0.14484269931912422,
#   0.144479069262743,
#   0.1439492806792259,
#   0.14375869005918504,
#   0.14303271904587744,
#   0.14223106428980828,
#   0.1417604875564575,
#   0.14119145452976226,
#   0.1406557174026966,
#   0.1400730988383293,
#   0.13968510866165162,
#   0.13885484218597413,
#   0.13829999312758445,
#   0.13781848013401032,
#   0.1372671316564083,
#   0.13672185003757475,
#   0.13611909359693528,
#   0.13567493379116058,
#   0.1351264861226082,
#   0.13477998375892639,
#   0.13417352706193925,
#   0.13392065063118935,
#   0.13320786535739898,
#   0.13224689424037933,
#   0.1316190692782402,
#   0.13102386713027955,
#   0.13013748645782472,
#   0.12942381232976913,
#   0.12867438778281212,
#   0.12775240570306778,
#   0.12692107290029525,
#   0.12622622206807135,
#   0.12540804326534272,
#   0.12457721918821335,
#   0.1236550772190094,
#   0.12286404222249984,
#   0.12209106907248497,
#   0.12129621252417565,
#   0.12069829866290092,
#   0.11982809662818909,
#   0.11903975993394851,
#   0.11851831272244454,
#   0.11735390678048134,
#   0.11650989562273026,
#   0.11571487739682197,
#   0.11493012234568596,
#   0.11414290487766265,
#   0.11337608441710473,
#   0.11256026938557624,
#   0.11187144532799721,
#   0.11102740123867988,
#   0.11035044834017754,
#   0.10951709523797035,
#   0.10880862534046173,
#   0.10815917924046517,
#   0.10723026104271412,
#   0.10649903528392315,
#   0.10592151887714862,
#   0.10492377698421479,
#   0.10434593312442303,
#   0.10335576735436916,
#   0.1026312469691038,
#   0.10208320111036301,
#   0.10101460352540016,
#   0.10029613867402076,
#   0.09980997405946254,
#   0.09869632840156556,
#   0.09800980642437934,
#   0.09729609996080399,
#   0.09631449848413468,
#   0.09555426329374313,
#   0.09489750109612942,
#   0.09444500461220741,
#   0.09413042426109314,
#   0.09273312628269195,
#   0.09290924891829491,
#   0.09216169767081737,
#   0.0916416036337614,
#   0.09113156549632549,
#   0.09087819173932075,
#   0.09024091333150863,
#   0.08970310874283313,
#   0.08942990396171809,
#   0.08886078760027885,
#   0.08835416965186596,
#   0.08793607976287604,
#   0.08759021401405334,
#   0.08685670152306557,
#   0.0835270120576024,
#   0.08334892965853215,
#   0.08301507379859686,
#   0.08262777287513018,
#   0.08227638270705938,
#   0.08194774355739355,
#   0.08162354197353125,
#   0.08130230348557234,
#   0.08107149861752987,
#   0.08041300553828477,
#   0.0793603714928031,
#   0.07903506934642791,
#   0.07860723564401269,
#   0.07837406054139137,
#   0.07817295106127858,
#   0.07722339743748308,
#   0.07672088142484426,
#   0.07673784159123898,
#   0.07658597983419896,
#   0.07658558189868928,
#   0.07651450766250491,
#   0.07627602599561215,
#   0.07618875306099654,
#   0.07619011789560318,
#   0.07570026343688369,
#   0.0747597723081708,
#   0.07368456248193979,
#   0.07500424347817898,
#   0.07381127222441136,
#   0.0740833749435842,
#   0.07284131042659282,
#   0.07232003215700387,
#   0.0720254304818809,
#   0.0719084608927369,
#   0.07256911415606737,
#   0.07203294919803739,
#   0.07168607376515865,
#   0.0713937727548182,
#   0.07124426454305649,
#   0.0714955477975309,
#   0.07081127882003785,
#   0.07046584187075496,
#   0.07097587682306766,
#   0.07022061828523875,
#   0.07072299921885133,
#   0.06977301953360439,
#   0.0696150253340602,
#   0.07026238335296511,
#   0.0691440201550722,
#   0.06992155279964209,
#   0.06948410134762525,
#   0.06986039606854319,
#   0.0696378274820745,
#   0.06825261294841767,
#   0.06955284900963306,
#   0.06879495702683926,
#   0.06926787834614516,
#   0.06888125358149409,
#   0.06934751423075795,
#   0.06725103897973896,
#   0.06855891540646553,
#   0.06765112390741707,
#   0.0670053550414741,
#   0.06754915879108012,
#   0.0663662637770176,
#   0.06672034891322255,
#   0.06636550076305867,
#   0.06572280397638679,
#   0.06587835164740681,
#   0.06568337382748723,
#   0.06509343596175313,
#   0.06518544122576714,
#   0.06481266606599093,
#   0.06441273801028728,
#   0.06413212927058339,
#   0.06397793792188168,
#   0.06382301773875952,
#   0.06358288610354065,
#   0.0636602459102869,
#   0.06321924538351595,
#   0.063083361312747,
#   0.06277771891094744,
#   0.06271441105753184,
#   0.06232957736589015,
#   0.062431739270687105,
#   0.06189859456382692,
#   0.06191595932468772,
#   0.06149197739548981,
#   0.06145198795944452,
#   0.06110880084335804,
#   0.06097372749820352,
#   0.06067782323807478,
#   0.06021362847648561,
#   0.06011474588885903,
#   0.05979901771992445,
#   0.05959099000319838,
#   0.059401107337325815,
#   0.05902616661041975,
#   0.05942765842191875,
#   0.058700985228642824,
#   0.05885726979933679,
#   0.0581583228521049,
#   0.057970058443024754,
#   0.05779285628348589,
#   0.05717107648961246,
#   0.057136441869661214,
#   0.057241096384823324,
#   0.05681396647356451,
#   0.05702011408284306,
#   0.0568111531669274,
#   0.05683340257033706,
#   0.05611146033741534,
#   0.05641966379247606,
#   0.05576979002449661,
#   0.05641547258011997,
#   0.055287258657626806,
#   0.05592622308060527,
#   0.054732879041694105,
#   0.05542560573201626,
#   0.054676190079189835,
#   0.05618140972219408,
#   0.05267890226095915,
#   0.05515140620060265,
#   0.05198146743234247,
#   0.05388485357630998,
#   0.05264437471982092,
#   0.05431931880768388,
#   0.05149902668781579,
#   0.053079890948720274,
#   0.0516266911639832,
#   0.053547871662303806,
#   0.05036137808812782,
#   0.051940797376446426,
#   0.050629075039178136,
#   0.051288130907341835,
#   0.05152108943555504,
#   0.05274161879438907,
#   0.04920637224800885,
#   0.05022497351747006,
#   0.04906590644503012,
#   0.04938140975311398,
#   0.04908585052937269,
#   0.04896848656237125,
#   0.04967071167426184,
#   0.04940414888085797,
#   0.04913741323631257,
#   0.05147547356085852,
#   0.052396952444687485,
#   0.05005309389904142,
#   0.04721435382496566,
#   0.04725997898727655,
#   0.04726053008344024,
#   0.04732098240405321,
#   0.046728702061809596,
#   0.04656877426197752,
#   0.046687886470463125,
#   0.04632524608168751,
#   0.0460390903474763,
#   0.04615440065972507,
#   0.04577493051998317,
#   0.04552611348684877,
#   0.04607447537593543,
#   0.052042995439842345,
#   0.04207142778206616,
#   0.05607652564533055,
#   0.04243301929440349,
#   0.06125386494153645,
#   0.04618892448255792,
#   0.045306460768915716,
#   0.0484956560889259,
#   0.045898266583681104,
#   0.044995829621329905,
#   0.04439187570009381],
#  [0.16992733353748918,
#   0.16815569000318648,
#   0.16696958242915572,
#   0.16600673797540366,
#   0.1651373833231628,
#   0.16459194416180253,
#   0.16422134219668805,
#   0.16381332102231683,
#   0.16331472838297487,
#   0.16301126547157765,
#   0.1625917213410139,
#   0.16229843128472565,
#   0.16197576271370054,
#   0.16161896554753186,
#   0.16134706519544126,
#   0.16093489686958493,
#   0.1605558436922729,
#   0.1600856650993228,
#   0.15968340085819363,
#   0.15925152020528913,
#   0.15869906689040364,
#   0.15819145672023296,
#   0.1575959432311356,
#   0.1569188799895346,
#   0.15589331481605767,
#   0.15522311011329293,
#   0.15443637371063232,
#   0.15369749141857028,
#   0.15302649607881905,
#   0.15229178585112094,
#   0.15157719217240812,
#   0.15082111770287157,
#   0.1500823500007391,
#   0.1493567804247141,
#   0.14871680609881877,
#   0.147999610286206,
#   0.14769258129410445,
#   0.14690267803147436,
#   0.14589153315871953,
#   0.14513225039467215,
#   0.14452942986041306,
#   0.14357806028798223,
#   0.14274235747754574,
#   0.14172088652849196,
#   0.14082212556153537,
#   0.13994989722967147,
#   0.1391174883209169,
#   0.13827583730220794,
#   0.13741254275664688,
#   0.13639577178284526,
#   0.13559768786653875,
#   0.13469556652009487,
#   0.13378932803869248,
#   0.1330043452978134,
#   0.13195134462788702,
#   0.1311247456818819,
#   0.13021456660702824,
#   0.1295552847161889,
#   0.12873515091836452,
#   0.12807634918950497,
#   0.12714690098538994,
#   0.12618553705513477,
#   0.12545861249789594,
#   0.12457707406952977,
#   0.12339321395382286,
#   0.12247602401301265,
#   0.1214548771083355,
#   0.12072437292896211,
#   0.11973310163244605,
#   0.1195909930113703,
#   0.1186572771705687,
#   0.11808252012357116,
#   0.11727095615118742,
#   0.11663668613880873,
#   0.11581658168695867,
#   0.11505092746578156,
#   0.11400153476279229,
#   0.11330084926448762,
#   0.11230830711312592,
#   0.11155361018609256,
#   0.11000397933181376,
#   0.1090210161311552,
#   0.10817440612707287,
#   0.10734526810236275,
#   0.1065162755548954,
#   0.10557398420758546,
#   0.10487502146977931,
#   0.10410142838954925,
#   0.10342236972413957,
#   0.10267568874638527,
#   0.1020002764929086,
#   0.10151397398207336,
#   0.10072009719908237,
#   0.10025333682075142,
#   0.09929275723639876,
#   0.09886823317967355,
#   0.09829610321903601,
#   0.0975804649782367,
#   0.09691883318591862,
#   0.09613430476514623,
#   0.09548223215853796,
#   0.09482251535635441,
#   0.09399070654064418,
#   0.09330472025554627,
#   0.09264772419119253,
#   0.09178087811218574,
#   0.09111068199155853,
#   0.09055804218747653,
#   0.08973092955187895,
#   0.08890561904991046,
#   0.08805593678960577,
#   0.08754069035639986,
#   0.08710870875045656,
#   0.08590284857433289,
#   0.08565162229700946,
#   0.08475778015796095,
#   0.08413135981885717,
#   0.08359298065071925,
#   0.08333230682241265,
#   0.08231851469259709,
#   0.08170274075120687,
#   0.08154488356900401,
#   0.08055272235535085,
#   0.08002012539829594,
#   0.07957025190582499,
#   0.07872426733607427,
#   0.07763060067140032,
#   0.07666458729829173,
#   0.07631108804955147,
#   0.07589026455243583,
#   0.07548700332234148,
#   0.07509680634422694,
#   0.07472887442127103,
#   0.07439595460979036,
#   0.0740779552940512,
#   0.0773330368209281,
#   0.07689423562173033,
#   0.07435820301849162,
#   0.0739803299443156,
#   0.0737017879691848,
#   0.07335768349832505,
#   0.07236961188973509,
#   0.07155889747155016,
#   0.07207890899604535,
#   0.0717831685298006,
#   0.07200534053336013,
#   0.07223854624768138,
#   0.0717513498381595,
#   0.07176566476773587,
#   0.07186384649583488,
#   0.07135007184908318,
#   0.06828761345932435,
#   0.06576559057444684,
#   0.0643798993872042,
#   0.06381596278457437,
#   0.06351633740792749,
#   0.06381148057880637,
#   0.06500685621067533,
#   0.064991554866574,
#   0.06713625070995477,
#   0.06823984028116684,
#   0.07017629826870689,
#   0.0712592797895195,
#   0.0713781464312342,
#   0.0711409478791029,
#   0.07044522083095217,
#   0.07094443995949405,
#   0.07067675988801056,
#   0.0697417326210416,
#   0.07040893767283705,
#   0.06902970680785074,
#   0.06979398729461536,
#   0.0686435906971019,
#   0.06734938991470699,
#   0.06819997718121158,
#   0.06550141055253335,
#   0.06553345098356658,
#   0.0652017004249501,
#   0.06492948001923651,
#   0.06481404488546104,
#   0.062472525513148865,
#   0.06280552193933545,
#   0.06252309247989615,
#   0.06218212237859916,
#   0.06188289558505858,
#   0.061629366443703475,
#   0.06003163518518704,
#   0.060085690476407765,
#   0.0596777536823538,
#   0.059251527796313895,
#   0.05900962634914322,
#   0.05854217808391695,
#   0.058332378463655916,
#   0.05802870898294714,
#   0.0577025478815267,
#   0.05749116598044566,
#   0.05728391789494708,
#   0.057027683663873174,
#   0.05698772006970103,
#   0.05680360777112583,
#   0.056393775335891405,
#   0.055967944792810156,
#   0.055677081802587056,
#   0.055431999279990124,
#   0.05508566025329856,
#   0.05513654529579071,
#   0.05461223007820081,
#   0.05460281775618569,
#   0.05408092447363742,
#   0.05430870538477393,
#   0.053652460792563944,
#   0.05400855947927994,
#   0.05300399290101268,
#   0.053634649548093875,
#   0.05267467652043706,
#   0.05337750651411625,
#   0.0522766562230754,
#   0.0529039166738221,
#   0.05181956795297083,
#   0.053315708072714185,
#   0.05141458062244055,
#   0.05284595904518938,
#   0.050990554152976986,
#   0.052750885673503944,
#   0.0506836868800383,
#   0.052162417085237396,
#   0.05108861988863282,
#   0.05086147109732338,
#   0.05194546178029668,
#   0.050010030728062704,
#   0.051229485253797974,
#   0.04961952523077343,
#   0.05175825233476644,
#   0.05025478144818408,
#   0.05048741972550488,
#   0.051844519814148955,
#   0.04954861288151733,
#   0.052494376459108025,
#   0.049258303284241266,
#   0.052030550961617336,
#   0.04899552318640417,
#   0.051946360041119986,
#   0.04881864339540698,
#   0.05234810472341451,
#   0.048455388479851536,
#   0.052196174520640855,
#   0.04907705251429434,
#   0.05282922570263508,
#   0.04860041243656269,
#   0.05238053894258428,
#   0.04965133453947601,
#   0.05211179629147864,
#   0.048903530883417264,
#   0.05203844251499049,
#   0.04948822583989568,
#   0.052177041160434784,
#   0.04912329055087866,
#   0.05212073145016347,
#   0.049536691000621434,
#   0.052981562276809196,
#   0.04840791085894125,
#   0.05220955130354014,
#   0.048564391759464344,
#   0.05334876314304438,
#   0.04914295183989452,
#   0.050564104040322494,
#   0.050956209804853644,
#   0.05133480818395128,
#   0.05264347933754379,
#   0.052990230715063265,
#   0.0511722660041778,
#   0.050595654767316776,
#   0.04992639621109447,
#   0.04937530890159223,
#   0.0494729636945658,
#   0.04908151572284169,
#   0.050024181164721994,
#   0.05011053461085794,
#   0.04992004641264657,
#   0.049580854640689724,
#   0.04963163432513966,
#   0.049280680876133826,
#   0.048716394050179586,
#   0.04852545495410368,
#   0.048218711253718995,
#   0.047550512629127295,
#   0.047212311030286856,
#   0.04675866762112719,
#   0.04555411451285181,
#   0.04427701640888472,
#   0.04461370995000379,
#   0.04649081543623652,
#   0.047391563360274634,
#   0.04579578766599525,
#   0.049301112312100485,
#   0.04584269099784706,
#   0.045570647829301834,
#   0.04319052474956834,
#   0.045279331649512644,
#   0.04358619670294047])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


def plot_decision_surface(model, test_loader, feature_range=(-2, 2), resolution=0.01):
    """
    Plots the decision surface of the model along with the test set observations.
    
    Args:
        model: Trained PyTorch model.
        test_loader: DataLoader for the test set.
        feature_range: Tuple (min, max) for the grid of features.
        resolution: Step size for the grid.
    """
    # Generate a grid of points
    x_min, x_max = feature_range
    y_min, y_max = feature_range
    xx, yy = np.meshgrid(
        np.arange(x_min, x_max, resolution),
        np.arange(y_min, y_max, resolution)
    )
    
    # Flatten the grid to feed into the model
    grid_points = np.c_[xx.ravel(), yy.ravel()]
    grid_points_tensor = torch.tensor(grid_points, dtype=torch.float32)
    
    # Get model predictions on the grid
    model.eval()
    with torch.no_grad():
        predictions = model(grid_points_tensor)
        print(predictions)
        predicted_labels = (predictions > 0.5).float().flatten()
        # (output > 0.5).float()
        print(predicted_labels)
    
    # Reshape predictions back to the grid shape
    Z = predicted_labels.reshape(xx.shape)
    
    # Plot decision surface
    plt.figure(figsize=(10, 6))
    plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.coolwarm)
    
    # Plot test data points
    for data, target in test_loader:
        data = data.numpy()
        target = target.numpy()
        plt.scatter(data[:, 0], data[:, 1], c=target, edgecolor='k', cmap=plt.cm.coolwarm, s=50, label='Test Data')
    
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='Class 0',
               markerfacecolor='red', markersize=10),
        Line2D([0], [0], marker='o', color='w', label='Class 1',
               markerfacecolor='blue', markersize=10)
    ]

    plt.title('Learned Decision Surface')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend(handles=legend_elements, loc='upper right')
    plt.grid(True)
    plt.show()

# %%
eval_file_path = "spiral_test.csv"
eval_batch_size = 4

test_loader = load_data(eval_file_path, eval_batch_size)
plot_decision_surface(model, test_loader, feature_range=(-20, 20), resolution=0.01)
# Out:
# tensor([[0.0116],
#         [0.0115],
#         [0.0115],
#         ...,
#         [1.0000],
#         [1.0000],
#         [1.0000]])
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
